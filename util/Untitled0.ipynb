# %%
from docutils import nodes
from docutils.parsers.rst import roles

# %%
nodes.__doc()__
# Out:
#   File "<ipython-input-2-72f9597d2c0f>", line 1
#     nodes.__doc()__
#                   ^
# SyntaxError: invalid syntax

# %%
help(nodes)
# Out:
# Help on module docutils.nodes in docutils:
#
# NAME
#     docutils.nodes - Docutils document tree element class library.
#
# FILE
#     /Users/seanpue/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/docutils/nodes.py
#
# DESCRIPTION
#     Classes in CamelCase are abstract base classes or auxiliary classes. The one
#     exception is `Text`, for a text (PCDATA) node; uppercase is used to
#     differentiate from element classes.  Classes in lower_case_with_underscores
#     are element classes, matching the XML element generic identifiers in the DTD_.
#
#     The position of each node (the level at which it can occur) is significant and
#     is represented by abstract base classes (`Root`, `Structural`, `Body`,
#     `Inline`, etc.).  Certain transformations will be easier because we can use
#     ``isinstance(node, base_class)`` to determine the position of the node in the
#     hierarchy.
#
#     .. _DTD: http://docutils.sourceforge.net/docs/ref/docutils.dtd
#
# CLASSES
#     __builtin__.object
#         Node
#             Element
#                 TextElement
#                     FixedTextElement
#             Text(Node, reprunicode)
#     __builtin__.unicode(__builtin__.basestring)
#         reprunicode
#     BackLinkable
#     Bibliographic
#         address(Bibliographic, FixedTextElement)
#         author(Bibliographic, TextElement)
#         authors(Bibliographic, Element)
#         contact(Bibliographic, TextElement)
#         copyright(Bibliographic, TextElement)
#         date(Bibliographic, TextElement)
#         docinfo(Bibliographic, Element)
#         organization(Bibliographic, TextElement)
#         revision(Bibliographic, TextElement)
#         status(Bibliographic, TextElement)
#         version(Bibliographic, TextElement)
#     Body
#         Admonition
#             admonition(Admonition, Element)
#             attention(Admonition, Element)
#             caution(Admonition, Element)
#             danger(Admonition, Element)
#             error(Admonition, Element)
#             hint(Admonition, Element)
#             important(Admonition, Element)
#             note(Admonition, Element)
#             tip(Admonition, Element)
#             warning(Admonition, Element)
#         General
#             block_quote(General, Element)
#             citation(General, BackLinkable, Element, Labeled, Targetable)
#             compound(General, Element)
#             container(General, Element)
#             doctest_block(General, FixedTextElement)
#             figure(General, Element)
#             footnote(General, BackLinkable, Element, Labeled, Targetable)
#             image(General, Inline, Element)
#             line_block(General, Element)
#             literal_block(General, FixedTextElement)
#             math_block(General, FixedTextElement)
#             paragraph(General, TextElement)
#             reference(General, Inline, Referential, TextElement)
#             table(General, Element)
#         Sequential
#             bullet_list(Sequential, Element)
#             definition_list(Sequential, Element)
#             enumerated_list(Sequential, Element)
#             field_list(Sequential, Element)
#             option_list(Sequential, Element)
#         Special
#             comment(Special, Invisible, FixedTextElement)
#             pending(Special, Invisible, Element)
#             raw(Special, Inline, PreBibliographic, FixedTextElement)
#             substitution_definition(Special, Invisible, TextElement)
#             system_message(Special, BackLinkable, PreBibliographic, Element)
#             target(Special, Invisible, Inline, TextElement, Targetable)
#     Inline
#         abbreviation(Inline, TextElement)
#         acronym(Inline, TextElement)
#         citation_reference(Inline, Referential, TextElement)
#         emphasis(Inline, TextElement)
#         footnote_reference(Inline, Referential, TextElement)
#         generated(Inline, TextElement)
#         inline(Inline, TextElement)
#         literal(Inline, TextElement)
#         math(Inline, TextElement)
#         problematic(Inline, TextElement)
#         strong(Inline, TextElement)
#         subscript(Inline, TextElement)
#         substitution_reference(Inline, TextElement)
#         superscript(Inline, TextElement)
#         title_reference(Inline, TextElement)
#     Labeled
#     NodeVisitor
#         GenericNodeVisitor
#             TreeCopyVisitor
#         SparseNodeVisitor
#     Part
#         attribution(Part, TextElement)
#         caption(Part, TextElement)
#         classifier(Part, TextElement)
#         colspec(Part, Element)
#         definition(Part, Element)
#         definition_list_item(Part, Element)
#         description(Part, Element)
#         entry(Part, Element)
#         field(Part, Element)
#         field_body(Part, Element)
#         field_name(Part, TextElement)
#         label(Part, TextElement)
#         legend(Part, Element)
#         line(Part, TextElement)
#         list_item(Part, Element)
#         option(Part, Element)
#         option_argument(Part, TextElement)
#         option_group(Part, Element)
#         option_list_item(Part, Element)
#         option_string(Part, TextElement)
#         row(Part, Element)
#         tbody(Part, Element)
#         term(Part, TextElement)
#         tgroup(Part, Element)
#         thead(Part, Element)
#     PreBibliographic
#         Decorative
#             decoration(Decorative, Element)
#             footer(Decorative, Element)
#             header(Decorative, Element)
#         Invisible
#     Resolvable
#         Referential
#         Targetable
#     Root
#         document(Root, Structural, Element)
#     Structural
#         section(Structural, Element)
#         sidebar(Structural, Element)
#         topic(Structural, Element)
#         transition(Structural, Element)
#     Titular
#         rubric(Titular, TextElement)
#         subtitle(Titular, PreBibliographic, TextElement)
#         title(Titular, PreBibliographic, TextElement)
#     exceptions.Exception(exceptions.BaseException)
#         TreePruningException
#             NodeFound
#             SkipChildren
#             SkipDeparture
#             SkipNode
#             SkipSiblings
#             StopTraversal
#
#     class Admonition(Body)
#
#     class BackLinkable
#      |  Methods defined here:
#      |
#      |  add_backref(self, refid)
#
#     class Bibliographic
#
#     class Body
#
#     class Decorative(PreBibliographic)
#
#     class Element(Node)
#      |  `Element` is the superclass to all specific elements.
#      |
#      |  Elements contain attributes and child nodes.  Elements emulate
#      |  dictionaries for attributes, indexing by attribute name (a string).  To
#      |  set the attribute 'att' to 'value', do::
#      |
#      |      element['att'] = 'value'
#      |
#      |  There are two special attributes: 'ids' and 'names'.  Both are
#      |  lists of unique identifiers, and names serve as human interfaces
#      |  to IDs.  Names are case- and whitespace-normalized (see the
#      |  fully_normalize_name() function), and IDs conform to the regular
#      |  expression ``[a-z](-?[a-z0-9]+)*`` (see the make_id() function).
#      |
#      |  Elements also emulate lists for child nodes (element nodes and/or text
#      |  nodes), indexing by integer.  To get the first child node, use::
#      |
#      |      element[0]
#      |
#      |  Elements may be constructed using the ``+=`` operator.  To add one new
#      |  child node to element, do::
#      |
#      |      element += node
#      |
#      |  This is equivalent to ``element.append(node)``.
#      |
#      |  To add a list of multiple child nodes at once, use the same ``+=``
#      |  operator::
#      |
#      |      element += [node1, node2]
#      |
#      |  This is equivalent to ``element.extend([node1, node2])``.
#      |
#      |  Method resolution order:
#      |      Element
#      |      Node
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, other)
#      |
#      |  __contains__ = hasattr(self, attr)
#      |
#      |  __delitem__(self, key)
#      |
#      |  __getitem__(self, key)
#      |
#      |  __iadd__(self, other)
#      |      Append a node or a list of nodes to `self.children`.
#      |
#      |  __init__(self, rawsource='', *children, **attributes)
#      |
#      |  __len__(self)
#      |
#      |  __radd__(self, other)
#      |
#      |  __repr__(self)
#      |
#      |  __setitem__(self, key, item)
#      |
#      |  __unicode__(self)
#      |
#      |  append(self, item)
#      |
#      |  append_attr_list(self, attr, values)
#      |      For each element in values, if it does not exist in self[attr], append
#      |      it.
#      |
#      |      NOTE: Requires self[attr] and values to be sequence type and the
#      |      former should specifically be a list.
#      |
#      |  astext(self)
#      |
#      |  attlist(self)
#      |
#      |  clear(self)
#      |
#      |  coerce_append_attr_list(self, attr, value)
#      |      First, convert both self[attr] and value to a non-string sequence
#      |      type; if either is not already a sequence, convert it to a list of one
#      |      element.  Then call append_attr_list.
#      |
#      |      NOTE: self[attr] and value both must not be None.
#      |
#      |  copy(self)
#      |
#      |  copy_attr_coerce(self, attr, value, replace)
#      |      If attr is an attribute of self and either self[attr] or value is a
#      |      list, convert all non-sequence values to a sequence of 1 element and
#      |      then concatenate the two sequence, setting the result to self[attr].
#      |      If both self[attr] and value are non-sequences and replace is True or
#      |      self[attr] is None, replace self[attr] with value. Otherwise, do
#      |      nothing.
#      |
#      |  copy_attr_concatenate(self, attr, value, replace)
#      |      If attr is an attribute of self and both self[attr] and value are
#      |      lists, concatenate the two sequences, setting the result to
#      |      self[attr].  If either self[attr] or value are non-sequences and
#      |      replace is True or self[attr] is None, replace self[attr] with value.
#      |      Otherwise, do nothing.
#      |
#      |  copy_attr_consistent(self, attr, value, replace)
#      |      If replace is True or selfpattr] is None, replace self[attr] with
#      |      value.  Otherwise, do nothing.
#      |
#      |  copy_attr_convert(self, attr, value, replace=True)
#      |      If attr is an attribute of self, set self[attr] to
#      |      [self[attr], value], otherwise set self[attr] to value.
#      |
#      |      NOTE: replace is not used by this function and is kept only for
#      |            compatibility with the other copy functions.
#      |
#      |  deepcopy(self)
#      |
#      |  delattr(self, attr)
#      |
#      |  emptytag(self)
#      |
#      |  endtag(self)
#      |
#      |  extend(self, item)
#      |
#      |  first_child_matching_class(self, childclass, start=0, end=9223372036854775807)
#      |      Return the index of the first child whose class exactly matches.
#      |
#      |      Parameters:
#      |
#      |      - `childclass`: A `Node` subclass to search for, or a tuple of `Node`
#      |        classes. If a tuple, any of the classes may match.
#      |      - `start`: Initial index to check.
#      |      - `end`: Initial index to *not* check.
#      |
#      |  first_child_not_matching_class(self, childclass, start=0, end=9223372036854775807)
#      |      Return the index of the first child whose class does *not* match.
#      |
#      |      Parameters:
#      |
#      |      - `childclass`: A `Node` subclass to skip, or a tuple of `Node`
#      |        classes. If a tuple, none of the classes may match.
#      |      - `start`: Initial index to check.
#      |      - `end`: Initial index to *not* check.
#      |
#      |  get(self, key, failobj=None)
#      |
#      |  get_language_code(self, fallback='')
#      |      Return node's language tag.
#      |
#      |      Look iteratively in self and parents for a class argument
#      |      starting with ``language-`` and return the remainder of it
#      |      (which should be a `BCP49` language tag) or the `fallback`.
#      |
#      |  has_key = hasattr(self, attr)
#      |
#      |  hasattr(self, attr)
#      |
#      |  index(self, item)
#      |
#      |  insert(self, index, item)
#      |
#      |  is_not_default(self, key)
#      |
#      |  non_default_attributes(self)
#      |
#      |  note_referenced_by(self, name=None, id=None)
#      |      Note that this Element has been referenced by its name
#      |      `name` or id `id`.
#      |
#      |  pformat(self, indent='    ', level=0)
#      |
#      |  pop(self, i=-1)
#      |
#      |  remove(self, item)
#      |
#      |  replace(self, old, new)
#      |      Replace one child `Node` with another child or children.
#      |
#      |  replace_attr(self, attr, value, force=True)
#      |      If self[attr] does not exist or force is True or omitted, set
#      |      self[attr] to value, otherwise do nothing.
#      |
#      |  replace_self(self, new)
#      |      Replace `self` node with `new`, where `new` is a node or a
#      |      list of nodes.
#      |
#      |  set_class(self, name)
#      |      Add a new class to the "classes" attribute.
#      |
#      |  setdefault(self, key, failobj=None)
#      |
#      |  shortrepr(self)
#      |
#      |  starttag(self, quoteattr=None)
#      |
#      |  update_all_atts(self, dict_, update_fun=<function copy_attr_consistent>, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_, the two values are
#      |      merged based on the value of update_fun.  Generally, when replace is
#      |      True, the values in self are replaced or merged with the values in
#      |      dict_; otherwise, the values in self may be preserved or merged.  When
#      |      and_source is True, the 'source' attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |      NOTE: It is easier to call the update-specific methods then to pass
#      |            the update_fun method to this function.
#      |
#      |  update_all_atts_coercion(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values are both
#      |      not lists and replace is True, the values in self are replaced with
#      |      the values in dict_; if either of the values from self and dict_ for
#      |      the given identifier are of list type, then first any non-lists are
#      |      converted to 1-element lists and then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_concatenating(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values aren't each
#      |      lists and replace is True, the values in self are replaced with the
#      |      values in dict_; if the values from self and dict_ for the given
#      |      identifier are both of list type, then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_consistantly(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ and replace is True, the
#      |      values in self are replaced with the values in dict_; otherwise, the
#      |      values in self are preserved.  When and_source is True, the 'source'
#      |      attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_convert(self, dict_, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ then first any non-lists
#      |      are converted to 1-element lists and then the two lists are
#      |      concatenated and the result stored in self; otherwise, the values in
#      |      self are preserved.  When and_source is True, the 'source' attribute
#      |      is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_basic_atts(self, dict_)
#      |      Update basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') from node or dictionary `dict_`.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods defined here:
#      |
#      |  is_not_known_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT recognized by
#      |      this class.
#      |
#      |  is_not_list_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT one of the
#      |      basic list attributes defined for all Elements.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  basic_attributes = ('ids', 'classes', 'names', 'dupnames')
#      |
#      |  child_text_separator = '\n\n'
#      |
#      |  known_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs',...
#      |
#      |  list_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs')
#      |
#      |  local_attributes = ('backrefs',)
#      |
#      |  tagname = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Node:
#      |
#      |  __nonzero__(self)
#      |      Node instances are always true, even if they're empty.  A node is more
#      |      than a simple container.  Its boolean "truth" does not depend on
#      |      having one or more subnodes in the doctree.
#      |
#      |      Use `len()` to check node length.  Use `None` to represent a boolean
#      |      false value.
#      |
#      |  __str__(self)
#      |      # on 2.x, str(node) will be a byte string with Unicode
#      |      # characters > 255 escaped; on 3.x this is no longer necessary
#      |
#      |  asdom(self, dom=None)
#      |      Return a DOM **fragment** representation of this Node.
#      |
#      |  next_node(self, condition=None, include_self=False, descend=True, siblings=False, ascend=False)
#      |      Return the first node in the iterable returned by traverse(),
#      |      or None if the iterable is empty.
#      |
#      |      Parameter list is the same as of traverse.  Note that
#      |      include_self defaults to 0, though.
#      |
#      |  setup_child(self, child)
#      |
#      |  traverse(self, condition=None, include_self=True, descend=True, siblings=False, ascend=False)
#      |      Return an iterable containing
#      |
#      |      * self (if include_self is true)
#      |      * all descendants in tree traversal order (if descend is true)
#      |      * all siblings (if siblings is true) and their descendants (if
#      |        also descend is true)
#      |      * the siblings of the parent (if ascend is true) and their
#      |        descendants (if also descend is true), and so on
#      |
#      |      If `condition` is not None, the iterable contains only nodes
#      |      for which ``condition(node)`` is true.  If `condition` is a
#      |      node class ``cls``, it is equivalent to a function consisting
#      |      of ``return isinstance(node, cls)``.
#      |
#      |      If ascend is true, assume siblings to be true as well.
#      |
#      |      For example, given the following tree::
#      |
#      |          <paragraph>
#      |              <emphasis>      <--- emphasis.traverse() and
#      |                  <strong>    <--- strong.traverse() are called.
#      |                      Foo
#      |                  Bar
#      |              <reference name="Baz" refid="baz">
#      |                  Baz
#      |
#      |      Then list(emphasis.traverse()) equals ::
#      |
#      |          [<emphasis>, <strong>, <#text: Foo>, <#text: Bar>]
#      |
#      |      and list(strong.traverse(ascend=True)) equals ::
#      |
#      |          [<strong>, <#text: Foo>, <#text: Bar>, <reference>, <#text: Baz>]
#      |
#      |  walk(self, visitor)
#      |      Traverse a tree of `Node` objects, calling the
#      |      `dispatch_visit()` method of `visitor` when entering each
#      |      node.  (The `walkabout()` method is similar, except it also
#      |      calls the `dispatch_departure()` method before exiting each
#      |      node.)
#      |
#      |      This tree traversal supports limited in-place tree
#      |      modifications.  Replacing one node with one or more nodes is
#      |      OK, as is removing an element.  However, if the node removed
#      |      or replaced occurs after the current node, the old node will
#      |      still be traversed, and any new nodes will not.
#      |
#      |      Within ``visit`` methods (and ``depart`` methods for
#      |      `walkabout()`), `TreePruningException` subclasses may be raised
#      |      (`SkipChildren`, `SkipSiblings`, `SkipNode`, `SkipDeparture`).
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` implementation for each `Node` subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  walkabout(self, visitor)
#      |      Perform a tree traversal similarly to `Node.walk()` (which
#      |      see), except also call the `dispatch_departure()` method
#      |      before exiting each node.
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` and ``depart`` implementation for each `Node`
#      |      subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Node:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from Node:
#      |
#      |  document = None
#      |
#      |  line = None
#      |
#      |  parent = None
#      |
#      |  source = None
#
#     class FixedTextElement(TextElement)
#      |  An element which directly contains preformatted text.
#      |
#      |  Method resolution order:
#      |      FixedTextElement
#      |      TextElement
#      |      Element
#      |      Node
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, rawsource='', text='', *children, **attributes)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from TextElement:
#      |
#      |  child_text_separator = ''
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Element:
#      |
#      |  __add__(self, other)
#      |
#      |  __contains__ = hasattr(self, attr)
#      |
#      |  __delitem__(self, key)
#      |
#      |  __getitem__(self, key)
#      |
#      |  __iadd__(self, other)
#      |      Append a node or a list of nodes to `self.children`.
#      |
#      |  __len__(self)
#      |
#      |  __radd__(self, other)
#      |
#      |  __repr__(self)
#      |
#      |  __setitem__(self, key, item)
#      |
#      |  __unicode__(self)
#      |
#      |  append(self, item)
#      |
#      |  append_attr_list(self, attr, values)
#      |      For each element in values, if it does not exist in self[attr], append
#      |      it.
#      |
#      |      NOTE: Requires self[attr] and values to be sequence type and the
#      |      former should specifically be a list.
#      |
#      |  astext(self)
#      |
#      |  attlist(self)
#      |
#      |  clear(self)
#      |
#      |  coerce_append_attr_list(self, attr, value)
#      |      First, convert both self[attr] and value to a non-string sequence
#      |      type; if either is not already a sequence, convert it to a list of one
#      |      element.  Then call append_attr_list.
#      |
#      |      NOTE: self[attr] and value both must not be None.
#      |
#      |  copy(self)
#      |
#      |  copy_attr_coerce(self, attr, value, replace)
#      |      If attr is an attribute of self and either self[attr] or value is a
#      |      list, convert all non-sequence values to a sequence of 1 element and
#      |      then concatenate the two sequence, setting the result to self[attr].
#      |      If both self[attr] and value are non-sequences and replace is True or
#      |      self[attr] is None, replace self[attr] with value. Otherwise, do
#      |      nothing.
#      |
#      |  copy_attr_concatenate(self, attr, value, replace)
#      |      If attr is an attribute of self and both self[attr] and value are
#      |      lists, concatenate the two sequences, setting the result to
#      |      self[attr].  If either self[attr] or value are non-sequences and
#      |      replace is True or self[attr] is None, replace self[attr] with value.
#      |      Otherwise, do nothing.
#      |
#      |  copy_attr_consistent(self, attr, value, replace)
#      |      If replace is True or selfpattr] is None, replace self[attr] with
#      |      value.  Otherwise, do nothing.
#      |
#      |  copy_attr_convert(self, attr, value, replace=True)
#      |      If attr is an attribute of self, set self[attr] to
#      |      [self[attr], value], otherwise set self[attr] to value.
#      |
#      |      NOTE: replace is not used by this function and is kept only for
#      |            compatibility with the other copy functions.
#      |
#      |  deepcopy(self)
#      |
#      |  delattr(self, attr)
#      |
#      |  emptytag(self)
#      |
#      |  endtag(self)
#      |
#      |  extend(self, item)
#      |
#      |  first_child_matching_class(self, childclass, start=0, end=9223372036854775807)
#      |      Return the index of the first child whose class exactly matches.
#      |
#      |      Parameters:
#      |
#      |      - `childclass`: A `Node` subclass to search for, or a tuple of `Node`
#      |        classes. If a tuple, any of the classes may match.
#      |      - `start`: Initial index to check.
#      |      - `end`: Initial index to *not* check.
#      |
#      |  first_child_not_matching_class(self, childclass, start=0, end=9223372036854775807)
#      |      Return the index of the first child whose class does *not* match.
#      |
#      |      Parameters:
#      |
#      |      - `childclass`: A `Node` subclass to skip, or a tuple of `Node`
#      |        classes. If a tuple, none of the classes may match.
#      |      - `start`: Initial index to check.
#      |      - `end`: Initial index to *not* check.
#      |
#      |  get(self, key, failobj=None)
#      |
#      |  get_language_code(self, fallback='')
#      |      Return node's language tag.
#      |
#      |      Look iteratively in self and parents for a class argument
#      |      starting with ``language-`` and return the remainder of it
#      |      (which should be a `BCP49` language tag) or the `fallback`.
#      |
#      |  has_key = hasattr(self, attr)
#      |
#      |  hasattr(self, attr)
#      |
#      |  index(self, item)
#      |
#      |  insert(self, index, item)
#      |
#      |  is_not_default(self, key)
#      |
#      |  non_default_attributes(self)
#      |
#      |  note_referenced_by(self, name=None, id=None)
#      |      Note that this Element has been referenced by its name
#      |      `name` or id `id`.
#      |
#      |  pformat(self, indent='    ', level=0)
#      |
#      |  pop(self, i=-1)
#      |
#      |  remove(self, item)
#      |
#      |  replace(self, old, new)
#      |      Replace one child `Node` with another child or children.
#      |
#      |  replace_attr(self, attr, value, force=True)
#      |      If self[attr] does not exist or force is True or omitted, set
#      |      self[attr] to value, otherwise do nothing.
#      |
#      |  replace_self(self, new)
#      |      Replace `self` node with `new`, where `new` is a node or a
#      |      list of nodes.
#      |
#      |  set_class(self, name)
#      |      Add a new class to the "classes" attribute.
#      |
#      |  setdefault(self, key, failobj=None)
#      |
#      |  shortrepr(self)
#      |
#      |  starttag(self, quoteattr=None)
#      |
#      |  update_all_atts(self, dict_, update_fun=<function copy_attr_consistent>, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_, the two values are
#      |      merged based on the value of update_fun.  Generally, when replace is
#      |      True, the values in self are replaced or merged with the values in
#      |      dict_; otherwise, the values in self may be preserved or merged.  When
#      |      and_source is True, the 'source' attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |      NOTE: It is easier to call the update-specific methods then to pass
#      |            the update_fun method to this function.
#      |
#      |  update_all_atts_coercion(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values are both
#      |      not lists and replace is True, the values in self are replaced with
#      |      the values in dict_; if either of the values from self and dict_ for
#      |      the given identifier are of list type, then first any non-lists are
#      |      converted to 1-element lists and then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_concatenating(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values aren't each
#      |      lists and replace is True, the values in self are replaced with the
#      |      values in dict_; if the values from self and dict_ for the given
#      |      identifier are both of list type, then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_consistantly(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ and replace is True, the
#      |      values in self are replaced with the values in dict_; otherwise, the
#      |      values in self are preserved.  When and_source is True, the 'source'
#      |      attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_convert(self, dict_, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ then first any non-lists
#      |      are converted to 1-element lists and then the two lists are
#      |      concatenated and the result stored in self; otherwise, the values in
#      |      self are preserved.  When and_source is True, the 'source' attribute
#      |      is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_basic_atts(self, dict_)
#      |      Update basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') from node or dictionary `dict_`.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from Element:
#      |
#      |  is_not_known_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT recognized by
#      |      this class.
#      |
#      |  is_not_list_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT one of the
#      |      basic list attributes defined for all Elements.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from Element:
#      |
#      |  basic_attributes = ('ids', 'classes', 'names', 'dupnames')
#      |
#      |  known_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs',...
#      |
#      |  list_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs')
#      |
#      |  local_attributes = ('backrefs',)
#      |
#      |  tagname = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Node:
#      |
#      |  __nonzero__(self)
#      |      Node instances are always true, even if they're empty.  A node is more
#      |      than a simple container.  Its boolean "truth" does not depend on
#      |      having one or more subnodes in the doctree.
#      |
#      |      Use `len()` to check node length.  Use `None` to represent a boolean
#      |      false value.
#      |
#      |  __str__(self)
#      |      # on 2.x, str(node) will be a byte string with Unicode
#      |      # characters > 255 escaped; on 3.x this is no longer necessary
#      |
#      |  asdom(self, dom=None)
#      |      Return a DOM **fragment** representation of this Node.
#      |
#      |  next_node(self, condition=None, include_self=False, descend=True, siblings=False, ascend=False)
#      |      Return the first node in the iterable returned by traverse(),
#      |      or None if the iterable is empty.
#      |
#      |      Parameter list is the same as of traverse.  Note that
#      |      include_self defaults to 0, though.
#      |
#      |  setup_child(self, child)
#      |
#      |  traverse(self, condition=None, include_self=True, descend=True, siblings=False, ascend=False)
#      |      Return an iterable containing
#      |
#      |      * self (if include_self is true)
#      |      * all descendants in tree traversal order (if descend is true)
#      |      * all siblings (if siblings is true) and their descendants (if
#      |        also descend is true)
#      |      * the siblings of the parent (if ascend is true) and their
#      |        descendants (if also descend is true), and so on
#      |
#      |      If `condition` is not None, the iterable contains only nodes
#      |      for which ``condition(node)`` is true.  If `condition` is a
#      |      node class ``cls``, it is equivalent to a function consisting
#      |      of ``return isinstance(node, cls)``.
#      |
#      |      If ascend is true, assume siblings to be true as well.
#      |
#      |      For example, given the following tree::
#      |
#      |          <paragraph>
#      |              <emphasis>      <--- emphasis.traverse() and
#      |                  <strong>    <--- strong.traverse() are called.
#      |                      Foo
#      |                  Bar
#      |              <reference name="Baz" refid="baz">
#      |                  Baz
#      |
#      |      Then list(emphasis.traverse()) equals ::
#      |
#      |          [<emphasis>, <strong>, <#text: Foo>, <#text: Bar>]
#      |
#      |      and list(strong.traverse(ascend=True)) equals ::
#      |
#      |          [<strong>, <#text: Foo>, <#text: Bar>, <reference>, <#text: Baz>]
#      |
#      |  walk(self, visitor)
#      |      Traverse a tree of `Node` objects, calling the
#      |      `dispatch_visit()` method of `visitor` when entering each
#      |      node.  (The `walkabout()` method is similar, except it also
#      |      calls the `dispatch_departure()` method before exiting each
#      |      node.)
#      |
#      |      This tree traversal supports limited in-place tree
#      |      modifications.  Replacing one node with one or more nodes is
#      |      OK, as is removing an element.  However, if the node removed
#      |      or replaced occurs after the current node, the old node will
#      |      still be traversed, and any new nodes will not.
#      |
#      |      Within ``visit`` methods (and ``depart`` methods for
#      |      `walkabout()`), `TreePruningException` subclasses may be raised
#      |      (`SkipChildren`, `SkipSiblings`, `SkipNode`, `SkipDeparture`).
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` implementation for each `Node` subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  walkabout(self, visitor)
#      |      Perform a tree traversal similarly to `Node.walk()` (which
#      |      see), except also call the `dispatch_departure()` method
#      |      before exiting each node.
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` and ``depart`` implementation for each `Node`
#      |      subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Node:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from Node:
#      |
#      |  document = None
#      |
#      |  line = None
#      |
#      |  parent = None
#      |
#      |  source = None
#
#     class General(Body)
#
#     class GenericNodeVisitor(NodeVisitor)
#      |  Generic "Visitor" abstract superclass, for simple traversals.
#      |
#      |  Unless overridden, each ``visit_...`` method calls `default_visit()`, and
#      |  each ``depart_...`` method (when using `Node.walkabout()`) calls
#      |  `default_departure()`. `default_visit()` (and `default_departure()`) must
#      |  be overridden in subclasses.
#      |
#      |  Define fully generic visitors by overriding `default_visit()` (and
#      |  `default_departure()`) only. Define semi-generic visitors by overriding
#      |  individual ``visit_...()`` (and ``depart_...()``) methods also.
#      |
#      |  `NodeVisitor.unknown_visit()` (`NodeVisitor.unknown_departure()`) should
#      |  be overridden for default behavior.
#      |
#      |  Methods defined here:
#      |
#      |  default_departure(self, node)
#      |      Override for generic, uniform traversals.
#      |
#      |  default_visit(self, node)
#      |      Override for generic, uniform traversals.
#      |
#      |  depart_Text = _call_default_departure(self, node)
#      |
#      |  depart_abbreviation = _call_default_departure(self, node)
#      |
#      |  depart_acronym = _call_default_departure(self, node)
#      |
#      |  depart_address = _call_default_departure(self, node)
#      |
#      |  depart_admonition = _call_default_departure(self, node)
#      |
#      |  depart_attention = _call_default_departure(self, node)
#      |
#      |  depart_attribution = _call_default_departure(self, node)
#      |
#      |  depart_author = _call_default_departure(self, node)
#      |
#      |  depart_authors = _call_default_departure(self, node)
#      |
#      |  depart_block_quote = _call_default_departure(self, node)
#      |
#      |  depart_bullet_list = _call_default_departure(self, node)
#      |
#      |  depart_caption = _call_default_departure(self, node)
#      |
#      |  depart_caution = _call_default_departure(self, node)
#      |
#      |  depart_citation = _call_default_departure(self, node)
#      |
#      |  depart_citation_reference = _call_default_departure(self, node)
#      |
#      |  depart_classifier = _call_default_departure(self, node)
#      |
#      |  depart_colspec = _call_default_departure(self, node)
#      |
#      |  depart_comment = _call_default_departure(self, node)
#      |
#      |  depart_compound = _call_default_departure(self, node)
#      |
#      |  depart_contact = _call_default_departure(self, node)
#      |
#      |  depart_container = _call_default_departure(self, node)
#      |
#      |  depart_copyright = _call_default_departure(self, node)
#      |
#      |  depart_danger = _call_default_departure(self, node)
#      |
#      |  depart_date = _call_default_departure(self, node)
#      |
#      |  depart_decoration = _call_default_departure(self, node)
#      |
#      |  depart_definition = _call_default_departure(self, node)
#      |
#      |  depart_definition_list = _call_default_departure(self, node)
#      |
#      |  depart_definition_list_item = _call_default_departure(self, node)
#      |
#      |  depart_description = _call_default_departure(self, node)
#      |
#      |  depart_docinfo = _call_default_departure(self, node)
#      |
#      |  depart_doctest_block = _call_default_departure(self, node)
#      |
#      |  depart_document = _call_default_departure(self, node)
#      |
#      |  depart_emphasis = _call_default_departure(self, node)
#      |
#      |  depart_entry = _call_default_departure(self, node)
#      |
#      |  depart_enumerated_list = _call_default_departure(self, node)
#      |
#      |  depart_error = _call_default_departure(self, node)
#      |
#      |  depart_field = _call_default_departure(self, node)
#      |
#      |  depart_field_body = _call_default_departure(self, node)
#      |
#      |  depart_field_list = _call_default_departure(self, node)
#      |
#      |  depart_field_name = _call_default_departure(self, node)
#      |
#      |  depart_figure = _call_default_departure(self, node)
#      |
#      |  depart_footer = _call_default_departure(self, node)
#      |
#      |  depart_footnote = _call_default_departure(self, node)
#      |
#      |  depart_footnote_reference = _call_default_departure(self, node)
#      |
#      |  depart_generated = _call_default_departure(self, node)
#      |
#      |  depart_header = _call_default_departure(self, node)
#      |
#      |  depart_hint = _call_default_departure(self, node)
#      |
#      |  depart_image = _call_default_departure(self, node)
#      |
#      |  depart_important = _call_default_departure(self, node)
#      |
#      |  depart_inline = _call_default_departure(self, node)
#      |
#      |  depart_label = _call_default_departure(self, node)
#      |
#      |  depart_legend = _call_default_departure(self, node)
#      |
#      |  depart_line = _call_default_departure(self, node)
#      |
#      |  depart_line_block = _call_default_departure(self, node)
#      |
# ...
#      |      - `start`: Initial index to check.
#      |      - `end`: Initial index to *not* check.
#      |
#      |  get(self, key, failobj=None)
#      |
#      |  get_language_code(self, fallback='')
#      |      Return node's language tag.
#      |
#      |      Look iteratively in self and parents for a class argument
#      |      starting with ``language-`` and return the remainder of it
#      |      (which should be a `BCP49` language tag) or the `fallback`.
#      |
#      |  has_key = hasattr(self, attr)
#      |
#      |  hasattr(self, attr)
#      |
#      |  index(self, item)
#      |
#      |  insert(self, index, item)
#      |
#      |  is_not_default(self, key)
#      |
#      |  non_default_attributes(self)
#      |
#      |  note_referenced_by(self, name=None, id=None)
#      |      Note that this Element has been referenced by its name
#      |      `name` or id `id`.
#      |
#      |  pformat(self, indent='    ', level=0)
#      |
#      |  pop(self, i=-1)
#      |
#      |  remove(self, item)
#      |
#      |  replace(self, old, new)
#      |      Replace one child `Node` with another child or children.
#      |
#      |  replace_attr(self, attr, value, force=True)
#      |      If self[attr] does not exist or force is True or omitted, set
#      |      self[attr] to value, otherwise do nothing.
#      |
#      |  replace_self(self, new)
#      |      Replace `self` node with `new`, where `new` is a node or a
#      |      list of nodes.
#      |
#      |  set_class(self, name)
#      |      Add a new class to the "classes" attribute.
#      |
#      |  setdefault(self, key, failobj=None)
#      |
#      |  shortrepr(self)
#      |
#      |  starttag(self, quoteattr=None)
#      |
#      |  update_all_atts(self, dict_, update_fun=<function copy_attr_consistent>, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_, the two values are
#      |      merged based on the value of update_fun.  Generally, when replace is
#      |      True, the values in self are replaced or merged with the values in
#      |      dict_; otherwise, the values in self may be preserved or merged.  When
#      |      and_source is True, the 'source' attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |      NOTE: It is easier to call the update-specific methods then to pass
#      |            the update_fun method to this function.
#      |
#      |  update_all_atts_coercion(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values are both
#      |      not lists and replace is True, the values in self are replaced with
#      |      the values in dict_; if either of the values from self and dict_ for
#      |      the given identifier are of list type, then first any non-lists are
#      |      converted to 1-element lists and then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_concatenating(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ whose values aren't each
#      |      lists and replace is True, the values in self are replaced with the
#      |      values in dict_; if the values from self and dict_ for the given
#      |      identifier are both of list type, then the two lists are concatenated
#      |      and the result stored in self; otherwise, the values in self are
#      |      preserved.  When and_source is True, the 'source' attribute is
#      |      included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_consistantly(self, dict_, replace=True, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ and replace is True, the
#      |      values in self are replaced with the values in dict_; otherwise, the
#      |      values in self are preserved.  When and_source is True, the 'source'
#      |      attribute is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_all_atts_convert(self, dict_, and_source=False)
#      |      Updates all attributes from node or dictionary `dict_`.
#      |
#      |      Appends the basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') and then, for all other attributes in
#      |      dict_, updates the same attribute in self.  When attributes with the
#      |      same identifier appear in both self and dict_ then first any non-lists
#      |      are converted to 1-element lists and then the two lists are
#      |      concatenated and the result stored in self; otherwise, the values in
#      |      self are preserved.  When and_source is True, the 'source' attribute
#      |      is included in the copy.
#      |
#      |      NOTE: When replace is False, and self contains a 'source' attribute,
#      |            'source' is not replaced even when dict_ has a 'source'
#      |            attribute, though it may still be merged into a list depending
#      |            on the value of update_fun.
#      |
#      |  update_basic_atts(self, dict_)
#      |      Update basic attributes ('ids', 'names', 'classes',
#      |      'dupnames', but not 'source') from node or dictionary `dict_`.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from Element:
#      |
#      |  is_not_known_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT recognized by
#      |      this class.
#      |
#      |  is_not_list_attribute(cls, attr) from __builtin__.type
#      |      Returns True if and only if the given attribute is NOT one of the
#      |      basic list attributes defined for all Elements.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from Element:
#      |
#      |  basic_attributes = ('ids', 'classes', 'names', 'dupnames')
#      |
#      |  child_text_separator = '\n\n'
#      |
#      |  known_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs',...
#      |
#      |  list_attributes = ('ids', 'classes', 'names', 'dupnames', 'backrefs')
#      |
#      |  local_attributes = ('backrefs',)
#      |
#      |  tagname = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Node:
#      |
#      |  __nonzero__(self)
#      |      Node instances are always true, even if they're empty.  A node is more
#      |      than a simple container.  Its boolean "truth" does not depend on
#      |      having one or more subnodes in the doctree.
#      |
#      |      Use `len()` to check node length.  Use `None` to represent a boolean
#      |      false value.
#      |
#      |  __str__(self)
#      |      # on 2.x, str(node) will be a byte string with Unicode
#      |      # characters > 255 escaped; on 3.x this is no longer necessary
#      |
#      |  asdom(self, dom=None)
#      |      Return a DOM **fragment** representation of this Node.
#      |
#      |  next_node(self, condition=None, include_self=False, descend=True, siblings=False, ascend=False)
#      |      Return the first node in the iterable returned by traverse(),
#      |      or None if the iterable is empty.
#      |
#      |      Parameter list is the same as of traverse.  Note that
#      |      include_self defaults to 0, though.
#      |
#      |  setup_child(self, child)
#      |
#      |  traverse(self, condition=None, include_self=True, descend=True, siblings=False, ascend=False)
#      |      Return an iterable containing
#      |
#      |      * self (if include_self is true)
#      |      * all descendants in tree traversal order (if descend is true)
#      |      * all siblings (if siblings is true) and their descendants (if
#      |        also descend is true)
#      |      * the siblings of the parent (if ascend is true) and their
#      |        descendants (if also descend is true), and so on
#      |
#      |      If `condition` is not None, the iterable contains only nodes
#      |      for which ``condition(node)`` is true.  If `condition` is a
#      |      node class ``cls``, it is equivalent to a function consisting
#      |      of ``return isinstance(node, cls)``.
#      |
#      |      If ascend is true, assume siblings to be true as well.
#      |
#      |      For example, given the following tree::
#      |
#      |          <paragraph>
#      |              <emphasis>      <--- emphasis.traverse() and
#      |                  <strong>    <--- strong.traverse() are called.
#      |                      Foo
#      |                  Bar
#      |              <reference name="Baz" refid="baz">
#      |                  Baz
#      |
#      |      Then list(emphasis.traverse()) equals ::
#      |
#      |          [<emphasis>, <strong>, <#text: Foo>, <#text: Bar>]
#      |
#      |      and list(strong.traverse(ascend=True)) equals ::
#      |
#      |          [<strong>, <#text: Foo>, <#text: Bar>, <reference>, <#text: Baz>]
#      |
#      |  walk(self, visitor)
#      |      Traverse a tree of `Node` objects, calling the
#      |      `dispatch_visit()` method of `visitor` when entering each
#      |      node.  (The `walkabout()` method is similar, except it also
#      |      calls the `dispatch_departure()` method before exiting each
#      |      node.)
#      |
#      |      This tree traversal supports limited in-place tree
#      |      modifications.  Replacing one node with one or more nodes is
#      |      OK, as is removing an element.  However, if the node removed
#      |      or replaced occurs after the current node, the old node will
#      |      still be traversed, and any new nodes will not.
#      |
#      |      Within ``visit`` methods (and ``depart`` methods for
#      |      `walkabout()`), `TreePruningException` subclasses may be raised
#      |      (`SkipChildren`, `SkipSiblings`, `SkipNode`, `SkipDeparture`).
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` implementation for each `Node` subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  walkabout(self, visitor)
#      |      Perform a tree traversal similarly to `Node.walk()` (which
#      |      see), except also call the `dispatch_departure()` method
#      |      before exiting each node.
#      |
#      |      Parameter `visitor`: A `NodeVisitor` object, containing a
#      |      ``visit`` and ``depart`` implementation for each `Node`
#      |      subclass encountered.
#      |
#      |      Return true if we should stop the traversal.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Node:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from Node:
#      |
#      |  document = None
#      |
#      |  line = None
#      |
#      |  parent = None
#      |
#      |  source = None
#
# FUNCTIONS
#     dupname(node, name)
#
#     ensure_str(s)
#         Failsave conversion of `unicode` to `str`.
#
#     fully_normalize_name(name)
#         Return a case- and whitespace-normalized name.
#
#     make_id(string)
#         Convert `string` into an identifier and return it.
#
#         Docutils identifiers will conform to the regular expression
#         ``[a-z](-?[a-z0-9]+)*``.  For CSS compatibility, identifiers (the "class"
#         and "id" attributes) should have no underscores, colons, or periods.
#         Hyphens may be used.
#
#         - The `HTML 4.01 spec`_ defines identifiers based on SGML tokens:
#
#               ID and NAME tokens must begin with a letter ([A-Za-z]) and may be
#               followed by any number of letters, digits ([0-9]), hyphens ("-"),
#               underscores ("_"), colons (":"), and periods (".").
#
#         - However the `CSS1 spec`_ defines identifiers based on the "name" token,
#           a tighter interpretation ("flex" tokenizer notation; "latin1" and
#           "escape" 8-bit characters have been replaced with entities)::
#
#               unicode     \[0-9a-f]{1,4}
#               latin1      [&iexcl;-&yuml;]
#               escape      {unicode}|\[ -~&iexcl;-&yuml;]
#               nmchar      [-a-z0-9]|{latin1}|{escape}
#               name        {nmchar}+
#
#         The CSS1 "nmchar" rule does not include underscores ("_"), colons (":"),
#         or periods ("."), therefore "class" and "id" attributes should not contain
#         these characters. They should be replaced with hyphens ("-"). Combined
#         with HTML's requirements (the first character must be a letter; no
#         "unicode", "latin1", or "escape" characters), this results in the
#         ``[a-z](-?[a-z0-9]+)*`` pattern.
#
#         .. _HTML 4.01 spec: http://www.w3.org/TR/html401
#         .. _CSS1 spec: http://www.w3.org/TR/REC-CSS1
#
#     pseudo_quoteattr(value)
#         Quote attributes for pseudo-xml
#
#     serial_escape(value)
#         Escape string values that are elements of a list, for serialization.
#
#     whitespace_normalize_name(name)
#         Return a whitespace-normalized name.
#
# DATA
#     __docformat__ = 'reStructuredText'
#     node_class_names = ['Text', 'abbreviation', 'acronym', 'address', 'adm...

# %%
 node = nodes.image(
        uri='http://www.tortue.me/emoji/{0}.png'.format(text),
        alt=text,
        classes=['emoji'],
    )
